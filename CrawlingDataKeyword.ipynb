# %% [markdown]
# <a href="https://colab.research.google.com/github/zanthegreat18/DataCrawlingKeyword/blob/main/CrawlingDataKeyword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo[srv]
# !pip install requests
# !pip install beautifulsoup4

import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient
import random
import time

# Koneksi ke MongoDB Atlas
client = MongoClient("mongodb+srv://Ojan123:Ojan123@ojanmenolaklupa.lgx84xs.mongodb.net/")

def crawl_detik_keyword():
    base_url = 'https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah'
    collection = client['Crawling_Keyword']['pendidikan']

    # Tentukan jumlah halaman yang ingin di-crawl
    max_page = 10 #total halaman yg mau di crawl
    page = 1 #mulai crawl dari page 1
    while page <= max_page:  # Mengganti kondisi while dengan pembatasan halaman
        url = f'{base_url}&page={page}&result_type=relevansi'
        print(f' Crawling halaman {page} -> {url}')

    #membuka halaman artikel untuk parsing
        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'lxml')

        articles = soup.find_all('article')
        if not articles:
            print('✅ Tidak ada lagi artikel, proses crawling selesai.')
            break

        for artikel in articles:
            try:
                link_tag = artikel.find('a')
                link = link_tag['href'] if link_tag else None
                if not link:
                    print('❌ Link tidak ditemukan.')
                    continue

                judul_tag = artikel.find('h3')
                judul = judul_tag.text.strip() if judul_tag else None
                if not judul:
                    print('❌ Judul tidak ditemukan.')
                    continue

                # Cek duplikat berdasarkan link atau judul
                if collection.find_one({'link': link}) or collection.find_one({'judul': judul}):
                    print(f'⏩ Artikel sudah ada: {judul[:50]}...')
                    continue

                isi_res = requests.get(link)
                isi_soup = BeautifulSoup(isi_res.text, 'lxml')

                # Meta info
                tanggal_meta = isi_soup.find('meta', attrs={'name': 'dtk:publishdate'})
                tanggal = tanggal_meta['content'].strip() if tanggal_meta else 'Tanggal tidak ditemukan'

                author_meta = isi_soup.find('meta', attrs={'name': 'dtk:author'})
                author = author_meta['content'].strip() if author_meta else 'Tidak tersedia'

                description_meta = isi_soup.find('meta', attrs={'name': 'description'})
                description = description_meta['content'].strip() if description_meta else 'Deskripsi tidak ditemukan'

                tags_meta = isi_soup.find('meta', attrs={'name': 'keywords'})
                tags = tags_meta['content'].strip() if tags_meta else 'Tags tidak ditemukan'

                # Ambil isi berita
                body_content = isi_soup.find('div', class_='detail__body-text itp_bodycontent')
                if body_content and body_content.get('id') != 'detikdetailtext':
                    isi_paragraf_list = [p.get_text(strip=True) for p in body_content.find_all('p') if p.get_text(strip=True)]
                    isi_berita = ' '.join(isi_paragraf_list) if isi_paragraf_list else 'Isi berita tidak ditemukan'
                else:
                    fallback_paragraf = isi_soup.find_all('p')
                    isi_paragraf_list = [p.get_text(strip=True) for p in fallback_paragraf if p.get_text(strip=True)]
                    isi_berita = ' '.join(isi_paragraf_list) if isi_paragraf_list else 'Isi berita tidak ditemukan'

                # Ambil thumbnail
                thumbnail_meta = isi_soup.find('meta', attrs={'name': 'dtk:thumbnailUrl'}) or isi_soup.find('meta', attrs={'property': 'og:image'})
                thumbnail_url = thumbnail_meta['content'].strip() if thumbnail_meta else 'Thumbnail tidak ditemukan'

                # Simpan ke MongoDB
                collection.insert_one({
                    'judul': judul,
                    'tanggal': tanggal,
                    'author': author,
                    'description': description,
                    'tags': tags,
                    'link': link,
                    'isi_berita': isi_berita,
                    'thumbnail': thumbnail_url
                })
                print(f'✅ Simpan: {judul[:50]}...')

                time.sleep(random.uniform(0.1, 0.5))
            #jeda tiap data saat crawl

            except Exception as e:
                print(f'❌ Error saat proses artikel: {e}')

        page += 1 #next halaman ketika satu halaman selesai di crawl

# Jalankan crawler
crawl_detik_keyword()
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.11/dist-packages (4.12.0)
# WARNING: pymongo 4.12.0 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymongo[srv]) (2.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
#  Crawling halaman 1 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=1&result_type=relevansi
# ✅ Simpan: Katy Perry Pulang dari Luar Angkasa Kembali Bikin ...
# ✅ Simpan: Simak Jadwal Libur Anak Sekolah Menurut Kalender P...
# ✅ Simpan: Pemprov DKI Gaet Universitas Kuala Lumpur, Siap Ki...
# ✅ Simpan: From Ujung Kulon To USA: Kisah Yani, Anak Penjual ...
# ✅ Simpan: Pemkab Solok dan Manggarai Timur Sampaikan Kesiapa...
# ✅ Simpan: Apa Itu Nomor Pokok Sekolah Nasional NPSN? Ini Pen...
# ✅ Simpan: Unjuk Kreativitas Siswa SLB di Semarang Lewat Fest...
# ✅ Simpan: Sinergi Kemensos dan Daerah Entaskan Kemiskinan me...
# ✅ Simpan: Program Gratispol Diluncurkan, Warga Kaltim Bisa S...
# ✅ Simpan: Kadindik Jatim Sebut Ijazah Pekerja Ditahan Perusa...
# ✅ Simpan: Menkes Bolehkan Dokter PPDS Praktik Umum untuk Dap...
#  Crawling halaman 2 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=2&result_type=relevansi
# ✅ Simpan: Cara Yumna, Siswa yang Diterima 7 Kampus Luar Nege...
# ✅ Simpan: Komisi X DPR Bakal Tanya Mendikdasmen soal Siswa S...
# ✅ Simpan: SMA Unggulan, Sekolah Rakyat, dan Prioritas Pendid...
# ✅ Simpan: Demonstrasi Harga Jagung Anjlok Berujung Perusakan...
# ✅ Simpan: Kemenag Ambil Peran Godok Kurikulum Pendidikan Kar...
# ✅ Simpan: Kemensos Percayakan Pendidikan Karakter Sekolah Ra...
# ✅ Simpan: Intip SLB N 31 PKLK Negeri Pangkalpinang, Siswanya...
# ✅ Simpan: Mengenal Sekolah Rakyat, Upaya Putus Rantai Kemisk...
# ✅ Simpan: Bantu Pendidikan di Sekolah Pelosok Binaan Pijar L...
# ✅ Simpan: Ikhtiar Kawal Anggaran Pendidikan 20% APBN, Sekola...
# ✅ Simpan: Kakorlantas Polri Dukung Penuh Pendidikan Lalu Lin...
#  Crawling halaman 3 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=3&result_type=relevansi
# ✅ Simpan: Gubernur Terpilih Luthfi Jamin Pendidikan Gratis b...
# ✅ Simpan: Mendagri: Dana Pendidikan Daerah buat Renovasi Sek...
# ✅ Simpan: Pemkot Tangerang Beri Bantuan Pendidikan untuk Ana...
# ✅ Simpan: Kalender Pendidikan 2025 Jawa Timur, Kapan Libur S...
# ✅ Simpan: MK Wajibkan Pendidikan Agama di Sekolah, Kemendikd...
# ✅ Simpan: Wacana Sekolah Libur Selama Puasa 2025, Pakar Pend...
# ✅ Simpan: Bupati Sabu Raijua Kembali Diperiksa KPK...
# ✅ Simpan: Prabowo Perketat Pejabat ke Luar Negeri, Anggaran ...
# ✅ Simpan: Homeschooling vs Sekolah Formal: Memilih Pendidika...
# ✅ Simpan: Dampak Positif Pijar Sekolah terhadap Pendidikan d...
# ✅ Simpan: Kisah Ubed, Kepala Sekolah Muda yang Gagas Pendidi...
#  Crawling halaman 4 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=4&result_type=relevansi
# ✅ Simpan: Paslon GUS Ingin Pendidikan Tata Krama Diterapkan ...
# ✅ Simpan: Walkot Semarang Dorong Sekolah Swasta Serahkan Ija...
# ✅ Simpan: Pengamat Pendidikan Soroti Polusi Suara di Sekolah...
# ✅ Simpan: Program Sekolah Mantab Jadikan Pendidikan di Serga...
# ✅ Simpan: KPK Pilih Empat Sekolah Ini sebagai Acuan Penerapa...
# ✅ Simpan: Rodi Ingin Lubuklinggau Jadi Kota Pendidikan, Rach...
# ✅ Simpan: Bupati Sabu Raijua Diperiksa KPK...
# ✅ Simpan: Perlukah UN Kembali Diberlakukan Sekolah? Ini Pend...
# ✅ Simpan: Polri Tekankan Kesetaraan Pendidikan Polwan Bintar...
# ✅ Simpan: Video: Solusi Mendikdasmen Perluas Akses Pendidika...
# ✅ Simpan: Tekan Angka Putus Sekolah, Kemendikdasmen Dorong P...
#  Crawling halaman 5 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=5&result_type=relevansi
# ✅ Simpan: Berkat Program Pendidikan di Kediri Anak Putus Sek...
# ✅ Simpan: JPPI Ungkap 5 Dampak Efisiensi Anggaran Pendidikan...
# ✅ Simpan: Semangat Kartini Kombes Sumarni: dari Jual Kue hin...
# ✅ Simpan: China Tingkatkan Pendidikan Jasmani Rekrut Eks Atl...
# ✅ Simpan: Sekolah Internasional Dibangun di IKN, Jokowi: Ber...
# ✅ Simpan: Cak Imin soal Rencana Sekolah Rakyat: Agar Pendidi...
# ✅ Simpan: Doktor HC untuk AM Fatwa...
# ✅ Simpan: Video: Inggris Rancang Larangan Merokok-Vape di Lu...
# ✅ Simpan: Video Menko PMK soal Sekolah Ramadan: Libur Tidakn...
# ✅ Simpan: Andra Soni Tegaskan Sekolah Dilarang Study Tour ke...
# ✅ Simpan: 25 Contoh Pantun Pendidikan dan Maknanya, Cocok Bu...
#  Crawling halaman 6 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=6&result_type=relevansi
# ✅ Simpan: Perkenalkan Reyhan, Karateka Peraih Beasiswa Sekol...
# ✅ Simpan: Gubri Larang Sekolah Bikin Kegiatan di Luar, Kepse...
# ✅ Simpan: Mengapa Kartini Tiba-tiba Dikeluarkan dari Sekolah...
# ✅ Simpan: Biaya Sekolah-UKT Naik Bikin Kelompok Pendidikan I...
# ✅ Simpan: Telkom Ungkap Dampak Fitur CBT di Pijar Sekolah Ba...
# ✅ Simpan: KLHK Tekankan Pentingnya Pendidikan Lingkungan Lew...
# ✅ Simpan: Warisi Api Kartini: Ini Kiprah Rini Widyantini dal...
# ✅ Simpan: Sunyi PPDB di Sekolah Luar Biasa Tasikmalaya...
# ✅ Simpan: Jurus Telkom Bikin Mutu Pendidikan Sekolah Makin C...
# ✅ Simpan: Begini Inovasi Sekolah di Kota Malang Kembangkan D...
#  Crawling halaman 7 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=7&result_type=relevansi
# ✅ Simpan: Riwayat Pendidikan Bung Tomo: Sempat Putus Sekolah...
# ✅ Simpan: LM Anak Nikita Mirzani Disebut Mau Move On, Fokus ...
# ✅ Simpan: Polda Bali Buka Kegiatan Praktik Kerja Dalam Neger...
# ✅ Simpan: Semangat Kartini, SMA Negeri 1 Sidoarjo Dorong Sis...
# ✅ Simpan: Kemenag Susun Peraturan Menteri Baru Tentang Pendi...
# ✅ Simpan: Khofifah Optimistis Prestasi Siswa Jatim Makin Mon...
# ✅ Simpan: Pentingnya Pendidikan Seksual di Sekolah untuk Ceg...
# ✅ Simpan: Platform Digital Andalan Telkom Bikin Pendidikan d...
# ✅ Simpan: Jadwal SPMB 2025 Lengkap Penerimaan Murid Baru SD,...
# ✅ Simpan: Guru Besar UPI: Anggaran Pendidikan untuk Sekolah ...
#  Crawling halaman 8 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=8&result_type=relevansi
# ✅ Simpan: Video: Nikita Mirzani Pastikan LM Akan Sekolah Lag...
# ✅ Simpan: Biografi RA Kartini, Sosok Pejuang Emansipasi Wani...
# ✅ Simpan: Profil Raden Adipati Djojodiningrat, Sosok Bupati ...
# ✅ Simpan: Ratusan Siswa SMP di Buleleng Berpotensi Putus Sek...
# ✅ Simpan: Fokus Pendidikan, Radityo Egi Biayai Anak Putus Se...
# ✅ Simpan: Kapan Pendaftaran IPDN 2025 Dibuka? Cek Infonya...
# ✅ Simpan: Kemenkeu: Anggaran Pendidikan di K/L Rp 34 T Bukan...
# ✅ Simpan: Anggaran Pendidikan Tak Terserap Rp 111 T, DPR: Bi...
# ✅ Simpan: Peringatan Hari Kartini 21 April 2025 Apakah Libur...
# ✅ Simpan: Bank Daerah Salurkan KJP Tahap I 2025 buat 43.502 ...
#  Crawling halaman 9 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=9&result_type=relevansi
# ✅ Simpan: 421 Siswa Sekolah & Madrasah Bakal Jadi Sampel Pro...
# ✅ Simpan: Anggaran Pendidikan 2025 Rp 722 T untuk Peningkata...
# ✅ Simpan: Dukung Kualitas Pendidikan, Pegadaian Transformasi...
# ✅ Simpan: 8 Fakta Unik R.A Kartini yang Jarang Diungkap, Sud...
# ✅ Simpan: Marak Kekerasan di Sekolah, Psikolog: Pendidikan K...
# ✅ Simpan: 8 Ide Kegiatan Peringatan Hari Pendidikan Nasional...
# ✅ Simpan: Begini Cerita di Balik Usulan Penghapusan Sekolah ...
# ✅ Simpan: RI-Denmark Mau Kerja Sama Perkuat Layanan Pemadam ...
# ✅ Simpan: Lirik Lagu 'Ibu Kita Kartini' Ciptaan W.R. Supratm...
# ✅ Simpan: Hari Kartini 21 April 2025, Bagikan Semangat Karti...
#  Crawling halaman 10 -> https://www.detik.com/search/searchall?query=pendidikan%20luar%20sekolah&page=10&result_type=relevansi
# ✅ Simpan: 25 Contoh Pidato Singkat untuk Tugas Sekolah tenta...
# ✅ Simpan: M Nuh soal Anggaran Pendidikan untuk Dana Desa: Pe...
# ✅ Simpan: Mempertanyakan Relevansi Perayaan Hari Kartini dan...
# ✅ Simpan: PDIP DKI Dukung Perpisahan Tak di Luar Sekolah: Pr...
# ✅ Simpan: Koalisi Kawal Pendidikan Gelar Aksi di CFD Sudirma...
# ✅ Simpan: Pemkab Karawang Minta Sekolah Tak Study Tour ke Lu...
# ✅ Simpan: Disdik Jabar: Study Tour Sekolah Dilarang di Luar ...
# ✅ Simpan: Disdik Jakarta Imbau Sekolah Tak Bikin Acara Perpi...
# ✅ Simpan: Kapan Masuk Sekolah Ajaran Baru 2024/2025 di Jogja...
# ✅ Simpan: SMK Hadapi Tantangan Pembelajaran-Permintaan Indus...
